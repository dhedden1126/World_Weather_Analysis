# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
import requests
from config import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress
from citipy import citipy

# %%
# Starting URL for Weather Map API Call + API Key variable
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 81.14,
#   'feels_like': 82.11,
#   'temp_min': 78.01,
#   'temp_max': 84,
#   'pressure': 1012,
#   'humidity': 65},
#  'visibility': 10000,
#  'wind': {'speed': 10.29, 'deg': 190},
#  'clouds': {'all': 75},
#  'dt': 1598312287,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1598263299,
#   'sunset': 1598311902},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
lats = np.random.uniform(-90, 90, size=1500)
lngs = np.random.uniform(-90, 90, size=1500)
lat_lngs = zip(lats,lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 596

# %%
#Create a list for storing the data we pull
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval")
print("-----------------------------")

#Create the counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_conditions = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Conditions": city_conditions})
                          #"Date": city_date})


    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saldanha
# Processing Record 2 of Set 1 | qeshm
# Processing Record 3 of Set 1 | pangnirtung
# Processing Record 4 of Set 1 | kruisfontein
# Processing Record 5 of Set 1 | tambacounda
# Processing Record 6 of Set 1 | dakoro
# Processing Record 7 of Set 1 | orbetello
# Processing Record 8 of Set 1 | staryy nadym
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | bowmore
# Processing Record 12 of Set 1 | robertson
# Processing Record 13 of Set 1 | vrnjacka banja
# Processing Record 14 of Set 1 | grindavik
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | sept-iles
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | tashla
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | beyneu
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | toropets
# Processing Record 24 of Set 1 | shakawe
# Processing Record 25 of Set 1 | kosh-agach
# Processing Record 26 of Set 1 | alvorada
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | vardo
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | belmonte
# Processing Record 32 of Set 1 | jericho
# Processing Record 33 of Set 1 | luziania
# Processing Record 34 of Set 1 | melilla
# Processing Record 35 of Set 1 | bonthe
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | jumla
# Processing Record 38 of Set 1 | male
# Processing Record 39 of Set 1 | kamina
# Processing Record 40 of Set 1 | phalaborwa
# Processing Record 41 of Set 1 | millinocket
# Processing Record 42 of Set 1 | zamora
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | rehoboth
# Processing Record 46 of Set 1 | arlit
# Processing Record 47 of Set 1 | cayenne
# Processing Record 48 of Set 1 | saint-louis
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | ostrovnoy
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | taoudenni
# Processing Record 3 of Set 2 | grand gaube
# Processing Record 4 of Set 2 | marawi
# Processing Record 5 of Set 2 | opuwo
# Processing Record 6 of Set 2 | amiens
# Processing Record 7 of Set 2 | puerto quijarro
# Processing Record 8 of Set 2 | mahibadhoo
# Processing Record 9 of Set 2 | sala consilina
# Processing Record 10 of Set 2 | kismayo
# Processing Record 11 of Set 2 | tazmalt
# Processing Record 12 of Set 2 | kasempa
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | luanda
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | bud
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | marovoay
# Processing Record 23 of Set 2 | saint-francois
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | terrak
# Processing Record 26 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 2 | richards bay
# Processing Record 28 of Set 2 | teguldet
# Processing Record 29 of Set 2 | klaksvik
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | fasa
# Processing Record 33 of Set 2 | rawson
# Processing Record 34 of Set 2 | ourem
# Processing Record 35 of Set 2 | kavaratti
# Processing Record 36 of Set 2 | ndele
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | belyy yar
# Processing Record 39 of Set 2 | ygatimi
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | abu kamal
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | turtas
# Processing Record 45 of Set 2 | karasjok
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | krasnoselkup
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 3 | balkanabat
# Processing Record 2 of Set 3 | atocha
# Processing Record 3 of Set 3 | ferme-neuve
# Processing Record 4 of Set 3 | quatre cocos
# Processing Record 5 of Set 3 | bhadohi
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | tome-acu
# City not found. Skipping...
# Processing Record 8 of Set 3 | uthal
# Processing Record 9 of Set 3 | mosquera
# Processing Record 10 of Set 3 | itarema
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | amapa
# Processing Record 14 of Set 3 | coquimbo
# Processing Record 15 of Set 3 | jacqueville
# Processing Record 16 of Set 3 | escanaba
# Processing Record 17 of Set 3 | ugoofaaru
# Processing Record 18 of Set 3 | bria
# Processing Record 19 of Set 3 | tahta
# Processing Record 20 of Set 3 | tromso
# Processing Record 21 of Set 3 | sassandra
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | loandjili
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | inirida
# Processing Record 28 of Set 3 | nueva loja
# Processing Record 29 of Set 3 | macapa
# Processing Record 30 of Set 3 | sao francisco de assis
# Processing Record 31 of Set 3 | coihaique
# Processing Record 32 of Set 3 | porosozero
# Processing Record 33 of Set 3 | songea
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | japura
# Processing Record 36 of Set 3 | mogadishu
# Processing Record 37 of Set 3 | muli
# Processing Record 38 of Set 3 | omsk
# Processing Record 39 of Set 3 | guia lopes da laguna
# Processing Record 40 of Set 3 | nicolas bravo
# Processing Record 41 of Set 3 | antofagasta
# Processing Record 42 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 3 | vestmanna
# Processing Record 44 of Set 3 | vilhena
# Processing Record 45 of Set 3 | tashara
# Processing Record 46 of Set 3 | loncoche
# Processing Record 47 of Set 3 | yar-sale
# Processing Record 48 of Set 3 | leh
# Processing Record 49 of Set 3 | istiaia
# Processing Record 50 of Set 3 | sinnamary
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | ilhabela
# Processing Record 4 of Set 4 | sao filipe
# Processing Record 5 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 4 | mehamn
# Processing Record 7 of Set 4 | abu dhabi
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | matara
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | ulvik
# Processing Record 13 of Set 4 | inhambane
# Processing Record 14 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 4 | atasu
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | kalomo
# City not found. Skipping...
# Processing Record 18 of Set 4 | susurluk
# Processing Record 19 of Set 4 | galle
# Processing Record 20 of Set 4 | zonguldak
# Processing Record 21 of Set 4 | mazagao
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | saint-georges
# Processing Record 24 of Set 4 | nuevitas
# Processing Record 25 of Set 4 | raudeberg
# Processing Record 26 of Set 4 | khoy
# Processing Record 27 of Set 4 | dawlatabad
# Processing Record 28 of Set 4 | mgandu
# Processing Record 29 of Set 4 | ellisras
# Processing Record 30 of Set 4 | channel-port aux basques
# Processing Record 31 of Set 4 | tsiroanomandidy
# Processing Record 32 of Set 4 | manoel urbano
# Processing Record 33 of Set 4 | gambo
# Processing Record 34 of Set 4 | macas
# Processing Record 35 of Set 4 | lodeynoye pole
# Processing Record 36 of Set 4 | charleston
# Processing Record 37 of Set 4 | yarmouth
# Processing Record 38 of Set 4 | havelock
# Processing Record 39 of Set 4 | necochea
# Processing Record 40 of Set 4 | marinette
# Processing Record 41 of Set 4 | auriflama
# Processing Record 42 of Set 4 | olafsvik
# Processing Record 43 of Set 4 | cacoal
# Processing Record 44 of Set 4 | sao joao da barra
# Processing Record 45 of Set 4 | pauini
# Processing Record 46 of Set 4 | bengkulu
# Processing Record 47 of Set 4 | brewster
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | gonen
# Processing Record 1 of Set 5 | iguguno
# Processing Record 2 of Set 5 | ziway
# Processing Record 3 of Set 5 | soyo
# Processing Record 4 of Set 5 | dahuk
# Processing Record 5 of Set 5 | sapuyes
# Processing Record 6 of Set 5 | hobyo
# Processing Record 7 of Set 5 | tiznit
# Processing Record 8 of Set 5 | gargzdai
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | iskateley
# Processing Record 11 of Set 5 | brae
# Processing Record 12 of Set 5 | yanam
# Processing Record 13 of Set 5 | shubarkuduk
# Processing Record 14 of Set 5 | ayaviri
# Processing Record 15 of Set 5 | nicoya
# Processing Record 16 of Set 5 | catamarca
# Processing Record 17 of Set 5 | mosetse
# Processing Record 18 of Set 5 | luxeuil-les-bains
# Processing Record 19 of Set 5 | pyaozerskiy
# Processing Record 20 of Set 5 | ust-koksa
# Processing Record 21 of Set 5 | reconquista
# Processing Record 22 of Set 5 | labrea
# Processing Record 23 of Set 5 | alamor
# Processing Record 24 of Set 5 | berea
# Processing Record 25 of Set 5 | lima
# Processing Record 26 of Set 5 | tiszasuly
# Processing Record 27 of Set 5 | takoradi
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | nagapattinam
# Processing Record 30 of Set 5 | sambava
# Processing Record 31 of Set 5 | rodrigues alves
# Processing Record 32 of Set 5 | abong mbang
# Processing Record 33 of Set 5 | kashi
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | sayyan
# Processing Record 36 of Set 5 | gazanjyk
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | wolmaranstad
# City not found. Skipping...
# Processing Record 39 of Set 5 | ullapool
# Processing Record 40 of Set 5 | nouadhibou
# Processing Record 41 of Set 5 | hithadhoo
# Processing Record 42 of Set 5 | carbonia
# Processing Record 43 of Set 5 | turayf
# Processing Record 44 of Set 5 | qaqortoq
# Processing Record 45 of Set 5 | maceio
# Processing Record 46 of Set 5 | usogorsk
# Processing Record 47 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 5 | boa vista
# Processing Record 49 of Set 5 | abbeville
# Processing Record 50 of Set 5 | severodvinsk
# Processing Record 1 of Set 6 | rebrikha
# Processing Record 2 of Set 6 | tortosa
# Processing Record 3 of Set 6 | manicore
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | soubre
# Processing Record 6 of Set 6 | arraial do cabo
# Processing Record 7 of Set 6 | manacapuru
# Processing Record 8 of Set 6 | dolores
# Processing Record 9 of Set 6 | valparaiso
# Processing Record 10 of Set 6 | el alto
# Processing Record 11 of Set 6 | muravlenko
# Processing Record 12 of Set 6 | vestmannaeyjar
# Processing Record 13 of Set 6 | riaba
# City not found. Skipping...
# Processing Record 14 of Set 6 | kaka
# Processing Record 15 of Set 6 | sohna
# Processing Record 16 of Set 6 | rio gallegos
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | buchanan
# Processing Record 19 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 6 | hearst
# Processing Record 21 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 6 | havre-saint-pierre
# Processing Record 23 of Set 6 | buraydah
# Processing Record 24 of Set 6 | stornoway
# Processing Record 25 of Set 6 | nortelandia
# Processing Record 26 of Set 6 | caravelas
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | baghdad
# Processing Record 29 of Set 6 | dingle
# Processing Record 30 of Set 6 | macherla
# Processing Record 31 of Set 6 | altamira
# Processing Record 32 of Set 6 | barzas
# Processing Record 33 of Set 6 | maseru
# Processing Record 34 of Set 6 | sabha
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | garowe
# Processing Record 37 of Set 6 | emirdag
# Processing Record 38 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 6 | guanica
# Processing Record 40 of Set 6 | wana
# Processing Record 41 of Set 6 | sar-e pul
# Processing Record 42 of Set 6 | bilecik
# Processing Record 43 of Set 6 | beyla
# Processing Record 44 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 6 | pavino
# Processing Record 46 of Set 6 | yellapur
# Processing Record 47 of Set 6 | corrales
# Processing Record 48 of Set 6 | saint-joseph
# Processing Record 49 of Set 6 | hamilton
# Processing Record 50 of Set 6 | kargasok
# Processing Record 1 of Set 7 | husavik
# Processing Record 2 of Set 7 | nanortalik
# Processing Record 3 of Set 7 | abapo
# Processing Record 4 of Set 7 | tabuk
# Processing Record 5 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 7 | graaff-reinet
# Processing Record 7 of Set 7 | kemijarvi
# Processing Record 8 of Set 7 | korla
# Processing Record 9 of Set 7 | oranjemund
# Processing Record 10 of Set 7 | dubai
# Processing Record 11 of Set 7 | pavilosta
# Processing Record 12 of Set 7 | mercedes
# Processing Record 13 of Set 7 | cape canaveral
# Processing Record 14 of Set 7 | mezen
# Processing Record 15 of Set 7 | anderson
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 7 | tessalit
# Processing Record 18 of Set 7 | tupiza
# Processing Record 19 of Set 7 | saint-augustin
# Processing Record 20 of Set 7 | am timan
# Processing Record 21 of Set 7 | cidreira
# Processing Record 22 of Set 7 | ancud
# Processing Record 23 of Set 7 | maracacume
# Processing Record 24 of Set 7 | praia da vitoria
# Processing Record 25 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 7 | chapais
# Processing Record 27 of Set 7 | shuyskoye
# Processing Record 28 of Set 7 | havoysund
# Processing Record 29 of Set 7 | adrar
# Processing Record 30 of Set 7 | morant bay
# Processing Record 31 of Set 7 | choa saidan shah
# Processing Record 32 of Set 7 | aksu
# Processing Record 33 of Set 7 | krasnoarmeysk
# Processing Record 34 of Set 7 | viedma
# Processing Record 35 of Set 7 | fjellstrand
# Processing Record 36 of Set 7 | glen allen
# Processing Record 37 of Set 7 | misratah
# Processing Record 38 of Set 7 | aguimes
# Processing Record 39 of Set 7 | itaituba
# Processing Record 40 of Set 7 | kaberamaido
# Processing Record 41 of Set 7 | kalmunai
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | kulhudhuffushi
# Processing Record 44 of Set 7 | angoche
# Processing Record 45 of Set 7 | hauknes
# Processing Record 46 of Set 7 | pangody
# Processing Record 47 of Set 7 | moroni
# Processing Record 48 of Set 7 | high rock
# Processing Record 49 of Set 7 | george town
# Processing Record 50 of Set 7 | los llanos de aridane
# Processing Record 1 of Set 8 | sawakin
# Processing Record 2 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 8 | senigallia
# Processing Record 4 of Set 8 | hrodna
# Processing Record 5 of Set 8 | pokaran
# Processing Record 6 of Set 8 | chicama
# Processing Record 7 of Set 8 | bandarbeyla
# Processing Record 8 of Set 8 | novosokolniki
# Processing Record 9 of Set 8 | farah
# Processing Record 10 of Set 8 | maarianhamina
# Processing Record 11 of Set 8 | ust-tsilma
# Processing Record 12 of Set 8 | doka
# Processing Record 13 of Set 8 | altay
# Processing Record 14 of Set 8 | yozgat
# Processing Record 15 of Set 8 | zholymbet
# Processing Record 16 of Set 8 | novo aripuana
# Processing Record 17 of Set 8 | oussouye
# Processing Record 18 of Set 8 | seydisehir
# Processing Record 19 of Set 8 | san rafael
# Processing Record 20 of Set 8 | manama
# Processing Record 21 of Set 8 | ruwi
# Processing Record 22 of Set 8 | valenca
# Processing Record 23 of Set 8 | nara
# Processing Record 24 of Set 8 | beni
# Processing Record 25 of Set 8 | timbiqui
# Processing Record 26 of Set 8 | darfo
# Processing Record 27 of Set 8 | kayerkan
# Processing Record 28 of Set 8 | hambantota
# Processing Record 29 of Set 8 | muyezerskiy
# Processing Record 30 of Set 8 | talara
# Processing Record 31 of Set 8 | tutrakan
# Processing Record 32 of Set 8 | toktogul
# Processing Record 33 of Set 8 | sao felix do xingu
# Processing Record 34 of Set 8 | mlyniv
# Processing Record 35 of Set 8 | frankenberg
# Processing Record 36 of Set 8 | abnub
# Processing Record 37 of Set 8 | mangrol
# Processing Record 38 of Set 8 | puquio
# Processing Record 39 of Set 8 | beira
# Processing Record 40 of Set 8 | rorvik
# Processing Record 41 of Set 8 | alegrete
# Processing Record 42 of Set 8 | pascagoula
# Processing Record 43 of Set 8 | ostersund
# Processing Record 44 of Set 8 | guarapari
# Processing Record 45 of Set 8 | gerardmer
# Processing Record 46 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 8 | lalsk
# Processing Record 48 of Set 8 | volodarka
# Processing Record 49 of Set 8 | raga
# Processing Record 50 of Set 8 | sur
# Processing Record 1 of Set 9 | atar
# Processing Record 2 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 9 | nsanje
# Processing Record 4 of Set 9 | aranos
# Processing Record 5 of Set 9 | bongandanga
# Processing Record 6 of Set 9 | nicholasville
# Processing Record 7 of Set 9 | santa vitoria do palmar
# Processing Record 8 of Set 9 | parabel
# Processing Record 9 of Set 9 | saint-ambroise
# Processing Record 10 of Set 9 | najran
# Processing Record 11 of Set 9 | skagen
# Processing Record 12 of Set 9 | sitia
# Processing Record 13 of Set 9 | comodoro rivadavia
# Processing Record 14 of Set 9 | nuuk
# Processing Record 15 of Set 9 | nantucket
# Processing Record 16 of Set 9 | sindor
# Processing Record 17 of Set 9 | marathon
# Processing Record 18 of Set 9 | bridgetown
# Processing Record 19 of Set 9 | henties bay
# Processing Record 20 of Set 9 | paoua
# Processing Record 21 of Set 9 | eyl
# Processing Record 22 of Set 9 | maun
# Processing Record 23 of Set 9 | qasigiannguit
# Processing Record 24 of Set 9 | constitucion
# Processing Record 25 of Set 9 | colares
# Processing Record 26 of Set 9 | savannah bight
# Processing Record 27 of Set 9 | kang
# Processing Record 28 of Set 9 | kudahuvadhoo
# Processing Record 29 of Set 9 | kedarnath
# City not found. Skipping...
# Processing Record 30 of Set 9 | bardiyah
# Processing Record 31 of Set 9 | keetmanshoop
# Processing Record 32 of Set 9 | jonkoping
# Processing Record 33 of Set 9 | benton harbor
# Processing Record 34 of Set 9 | becerril
# Processing Record 35 of Set 9 | harlingen
# Processing Record 36 of Set 9 | gloucester
# Processing Record 37 of Set 9 | gamba
# Processing Record 38 of Set 9 | campestre
# Processing Record 39 of Set 9 | birjand
# Processing Record 40 of Set 9 | touros
# Processing Record 41 of Set 9 | san juan
# Processing Record 42 of Set 9 | olinda
# Processing Record 43 of Set 9 | peoria
# Processing Record 44 of Set 9 | ovalle
# Processing Record 45 of Set 9 | pombas
# Processing Record 46 of Set 9 | maine-soroa
# Processing Record 47 of Set 9 | caranavi
# Processing Record 48 of Set 9 | key west
# Processing Record 49 of Set 9 | oktyabrskoye
# Processing Record 50 of Set 9 | hualmay
# Processing Record 1 of Set 10 | road town
# Processing Record 2 of Set 10 | tokzar
# City not found. Skipping...
# Processing Record 3 of Set 10 | kathmandu
# Processing Record 4 of Set 10 | doha
# Processing Record 5 of Set 10 | kutum
# Processing Record 6 of Set 10 | nurobod
# Processing Record 7 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 10 | sheltozero
# Processing Record 9 of Set 10 | toamasina
# Processing Record 10 of Set 10 | aripuana
# Processing Record 11 of Set 10 | surt
# Processing Record 12 of Set 10 | porto novo
# Processing Record 13 of Set 10 | axim
# Processing Record 14 of Set 10 | codo
# Processing Record 15 of Set 10 | severnyy
# Processing Record 16 of Set 10 | piacabucu
# Processing Record 17 of Set 10 | senneterre
# Processing Record 18 of Set 10 | nizwa
# Processing Record 19 of Set 10 | giurgita
# Processing Record 20 of Set 10 | cururupu
# Processing Record 21 of Set 10 | peruibe
# Processing Record 22 of Set 10 | murindo
# Processing Record 23 of Set 10 | albany
# Processing Record 24 of Set 10 | tabou
# Processing Record 25 of Set 10 | weiden
# Processing Record 26 of Set 10 | berberati
# Processing Record 27 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 10 | carutapera
# Processing Record 29 of Set 10 | bargarh
# Processing Record 30 of Set 10 | jasper
# Processing Record 31 of Set 10 | lethem
# Processing Record 32 of Set 10 | trairi
# Processing Record 33 of Set 10 | skibbereen
# Processing Record 34 of Set 10 | praia
# Processing Record 35 of Set 10 | dwarka
# Processing Record 36 of Set 10 | terrasini
# Processing Record 37 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 38 of Set 10 | daniel flores
# Processing Record 39 of Set 10 | higuey
# City not found. Skipping...
# Processing Record 40 of Set 10 | isiro
# Processing Record 41 of Set 10 | brejinho
# Processing Record 42 of Set 10 | careiro da varzea
# Processing Record 43 of Set 10 | pese
# Processing Record 44 of Set 10 | grand-lahou
# Processing Record 45 of Set 10 | sisimiut
# Processing Record 46 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 10 | sorland
# Processing Record 48 of Set 10 | vuktyl
# Processing Record 49 of Set 10 | bathsheba
# Processing Record 50 of Set 10 | tucuma
# Processing Record 1 of Set 11 | jalu
# Processing Record 2 of Set 11 | mikhaylovsk
# Processing Record 3 of Set 11 | kanniyakumari
# Processing Record 4 of Set 11 | saint-pierre
# Processing Record 5 of Set 11 | ajaccio
# Processing Record 6 of Set 11 | dutlwe
# Processing Record 7 of Set 11 | gagnoa
# Processing Record 8 of Set 11 | bilma
# Processing Record 9 of Set 11 | thaba nchu
# Processing Record 10 of Set 11 | alenquer
# Processing Record 11 of Set 11 | bantry
# Processing Record 12 of Set 11 | anzio
# Processing Record 13 of Set 11 | puerto baquerizo moreno
# Processing Record 14 of Set 11 | kurchum
# Processing Record 15 of Set 11 | pocoes
# Processing Record 16 of Set 11 | cabinda
# Processing Record 17 of Set 11 | caapucu
# Processing Record 18 of Set 11 | inta
# Processing Record 19 of Set 11 | utrecht
# Processing Record 20 of Set 11 | ambanja
# Processing Record 21 of Set 11 | mantua
# Processing Record 22 of Set 11 | talcahuano
# Processing Record 23 of Set 11 | gao
# Processing Record 24 of Set 11 | presidencia roque saenz pena
# Processing Record 25 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 11 | primorsk
# Processing Record 27 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 11 | skalat
# Processing Record 29 of Set 11 | port-cartier
# Processing Record 30 of Set 11 | balc
# Processing Record 31 of Set 11 | bonavista
# Processing Record 32 of Set 11 | lusambo
# Processing Record 33 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 34 of Set 11 | porto walter
# Processing Record 35 of Set 11 | basqal
# Processing Record 36 of Set 11 | kolimvari
# City not found. Skipping...
# Processing Record 37 of Set 11 | agadez
# Processing Record 38 of Set 11 | port said
# Processing Record 39 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 42 of Set 11 | zolotukhino
# Processing Record 43 of Set 11 | shakhovskaya
# Processing Record 44 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 45 of Set 11 | colchester
# Processing Record 46 of Set 11 | port-gentil
# Processing Record 47 of Set 11 | aksum
# Processing Record 48 of Set 11 | ierapetra
# Processing Record 49 of Set 11 | santa marta
# Processing Record 50 of Set 11 | barcelos
# Processing Record 1 of Set 12 | geraldton
# Processing Record 2 of Set 12 | kokstad
# Processing Record 3 of Set 12 | sao fidelis
# Processing Record 4 of Set 12 | ludvika
# Processing Record 5 of Set 12 | englewood
# Processing Record 6 of Set 12 | mao
# Processing Record 7 of Set 12 | gasa
# Processing Record 8 of Set 12 | benguela
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | qena
# Processing Record 11 of Set 12 | san cristobal
# Processing Record 12 of Set 12 | virginia beach
# Processing Record 13 of Set 12 | moose factory
# Processing Record 14 of Set 12 | pangoa
# Processing Record 15 of Set 12 | miandrivazo
# Processing Record 16 of Set 12 | rosario
# Processing Record 17 of Set 12 | tazovskiy
# Processing Record 18 of Set 12 | salinas
# Processing Record 19 of Set 12 | manta
# Processing Record 20 of Set 12 | kempten
# Processing Record 21 of Set 12 | loiza
# Processing Record 22 of Set 12 | stranda
# Processing Record 23 of Set 12 | ereymentau
# Processing Record 24 of Set 12 | villa oliva
# City not found. Skipping...
# Processing Record 25 of Set 12 | sao gabriel da cachoeira
# Processing Record 26 of Set 12 | igatpuri
# Processing Record 27 of Set 12 | sile
# Processing Record 28 of Set 12 | shambu
# Processing Record 29 of Set 12 | solton
# Processing Record 30 of Set 12 | harrismith
# Processing Record 31 of Set 12 | mmabatho
# Processing Record 32 of Set 12 | walvis bay
# Processing Record 33 of Set 12 | clarence town
# Processing Record 34 of Set 12 | maragogi
# Processing Record 35 of Set 12 | aktash
# Processing Record 36 of Set 12 | les cayes
# Processing Record 37 of Set 12 | saint anthony
# Processing Record 38 of Set 12 | sturgeon falls
# Processing Record 39 of Set 12 | gat
# Processing Record 40 of Set 12 | maraa
# Processing Record 41 of Set 12 | parana
# Processing Record 42 of Set 12 | nioro
# Processing Record 43 of Set 12 | sargatskoye
# Processing Record 44 of Set 12 | suluktu
# Processing Record 45 of Set 12 | santa fe
# Processing Record 46 of Set 12 | patacamaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 0        Saldanha      ZA -33.01  17.94     48.20        81          98
# 1           Qeshm      IR  26.96  56.27     89.60        74          20
# 2     Pangnirtung      CA  66.15 -65.71     44.60        93          90
# 3    Kruisfontein      ZA -34.00  24.73     59.00        87         100
# 4     Tambacounda      SN  13.75 -13.76     82.40        83         100
# ..            ...     ...    ...    ...       ...       ...         ...
# 548         Nioro      GM  13.35 -15.75     76.66        93         100
# 549   Sargatskoye      RU  55.61  73.50     47.44        97           7
# 550       Suluktu      KG  39.93  69.57     75.20        44          46
# 551      Santa Fe      AR -31.63 -60.70     75.00        48          24
# 552    Patacamaya      BO -17.23 -67.92     45.19        62           2
#
#      Wind Speed       Current Conditions
# 0          1.12          overcast clouds
# 1         11.41               few clouds
# 2          2.95  light intensity drizzle
# 3          3.00          overcast clouds
# 4          6.93          overcast clouds
# ..          ...                      ...
# 548        6.24               light rain
# 549        6.04                clear sky
# 550       20.13         scattered clouds
# 551        1.99               few clouds
# 552       12.77                clear sky
#
# [553 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
